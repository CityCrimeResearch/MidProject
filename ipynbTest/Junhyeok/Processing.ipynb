# %%
# 기본 라이브러리
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 그래프 기본 테마 설정
# https://coldbrown.co.kr/2023/07/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%8B%A4%EC%A0%84%ED%8E%B8-08-seaborn-sns-set%EC%9D%84-%ED%86%B5%ED%95%B4-%EC%8A%A4%ED%83%80%EC%9D%BC-%EC%84%A4%EC%A0%95%ED%95%98%EA%B8%B0/
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 14
plt.rcParams['axes.unicode_minus'] = False

# 복잡한 통계 처리를 위한 라이브러리
from scipy import stats

# 필요한 패키지
import os

# %%
# 현재 경로 확인
os.getcwd()
# Out:
# 'c:\\Users\\admin\\Desktop'

# %%
# 상위 폴더로 이동
os.chdir('../../')

# %%
os.chdir(r'C:/Users/admin/Desktop/mid_project/MidProject')
# CSV 불러오기 (첫 2행 건너뜀)
crime5_df = pd.read_csv("data/raw/5대범죄+발생장소별+현황_20250529152113.csv", skiprows=2)
crime5_df
# Out:
#   범죄별(1)  범죄별(2)     소계  아파트 연립다세대  단독주택  기타거주시설(오피스텔 원룸 기숙사 등)  \
# 0      계      소계  86213      12656  2987                   2413
# 1      계      살인    150         49    19                      6
# 2      계      강도    129         13     4                     10
# 3      계  강간강제추행   5764        602   169                    352
# 4      계      절도  37038       3718   913                    709
# 5      계      폭력  43132       8274  1882                   1336
#
#    도로(고속자동차 보도/골목길 포함)  상점/창고  공중위생업소(숙박업소 목욕탕 등)  음식점·유흥업소  역 대합실  교통수단  \
# 0                16713  14246                2161      8047   1648  3125
# 1                   16      4                   3         7      2     1
# 2                   22     17                   9         7      1     5
# 3                  523    209                 702      1037    366   745
# 4                 5531  11983                 693      2369    583  1087
# 5                10621   2033                 754      4627    696  1287
#
# ...

# %%
crime5_df = pd.read_csv("data/raw/5대범죄+발생장소별+현황_20250529152113.csv", skiprows=2)
# '범죄별(1)' 제거
crime5_df = crime5_df.drop(crime5_df.columns[0], axis=1)
crime5_df
# Out:
#    범죄별(2)     소계  아파트 연립다세대  단독주택  기타거주시설(오피스텔 원룸 기숙사 등)  도로(고속자동차 보도/골목길 포함)  \
# 0      소계  86213      12656  2987                   2413                16713
# 1      살인    150         49    19                      6                   16
# 2      강도    129         13     4                     10                   22
# 3  강간강제추행   5764        602   169                    352                  523
# 4      절도  37038       3718   913                    709                 5531
# 5      폭력  43132       8274  1882                   1336                10621
#
#    상점/창고  공중위생업소(숙박업소 목욕탕 등)  음식점·유흥업소  역 대합실  교통수단 문화/체육/오락시설 학교/도서관/학원  \
# 0  14246                2161      8047   1648  3125       2304       881
# 1      4                   3         7      2     1          -         1
# 2     17                   9         7      1     5          5         -
# 3    209                 702      1037    366   745        179       123
# ...

# %%
# 컬럼명변경
crime5_df = crime5_df.rename(columns={'범죄별(2)': '5대범죄'})
crime5_df
# Out:
#      5대범죄     소계  아파트 연립다세대  단독주택  기타거주시설(오피스텔 원룸 기숙사 등)  도로(고속자동차 보도/골목길 포함)  \
# 0      소계  86213      12656  2987                   2413                16713
# 1      살인    150         49    19                      6                   16
# 2      강도    129         13     4                     10                   22
# 3  강간강제추행   5764        602   169                    352                  523
# 4      절도  37038       3718   913                    709                 5531
# 5      폭력  43132       8274  1882                   1336                10621
#
#    상점/창고  공중위생업소(숙박업소 목욕탕 등)  음식점·유흥업소  역 대합실  교통수단 문화/체육/오락시설 학교/도서관/학원  \
# 0  14246                2161      8047   1648  3125       2304       881
# 1      4                   3         7      2     1          -         1
# 2     17                   9         7      1     5          5         -
# 3    209                 702      1037    366   745        179       123
# ...

# %%
# 첫번째 컬럼을 인덱스로 지정한다. 
crime5_df.set_index('5대범죄', inplace=True)
crime5_df
# Out:
#            소계  아파트 연립다세대  단독주택  기타거주시설(오피스텔 원룸 기숙사 등)  도로(고속자동차 보도/골목길 포함)  \
# 5대범죄
# 소계      86213      12656  2987                   2413                16713
# 살인        150         49    19                      6                   16
# 강도        129         13     4                     10                   22
# 강간강제추행   5764        602   169                    352                  523
# 절도      37038       3718   913                    709                 5531
# 폭력      43132       8274  1882                   1336                10621
#
#         상점/창고  공중위생업소(숙박업소 목욕탕 등)  음식점·유흥업소  역 대합실  교통수단 문화/체육/오락시설 학교/도서관/학원  \
# 5대범죄
# 소계      14246                2161      8047   1648  3125       2304       881
# 살인          4                   3         7      2     1          -         1
# 강도         17                   9         7      1     5          5         -
# 강간강제추행    209                 702      1037    366   745        179       123
# ...

# %%
crime5_df
# Out:
#            소계  아파트 연립다세대  단독주택  기타거주시설(오피스텔 원룸 기숙사 등)  도로(고속자동차 보도/골목길 포함)  \
# 5대범죄
# 소계      86213      12656  2987                   2413                16713
# 살인        150         49    19                      6                   16
# 강도        129         13     4                     10                   22
# 강간강제추행   5764        602   169                    352                  523
# 절도      37038       3718   913                    709                 5531
# 폭력      43132       8274  1882                   1336                10621
#
#         상점/창고  공중위생업소(숙박업소 목욕탕 등)  음식점·유흥업소  역 대합실  교통수단 문화/체육/오락시설 학교/도서관/학원  \
# 5대범죄
# 소계      14246                2161      8047   1648  3125       2304       881
# 살인          4                   3         7      2     1          -         1
# 강도         17                   9         7      1     5          5         -
# 강간강제추행    209                 702      1037    366   745        179       123
# ...

# %%
# csv로 내보낸다.
crime5_df.to_csv('data/processed/5대범죄발생장소별.csv', encoding='utf-8-sig', index=True)
