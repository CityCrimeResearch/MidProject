# %%
import pandas as pd

# %%
df = pd.read_csv('경찰청_전국 경찰서별 강력범죄 발생 현황_20231231.csv', encoding='EUC-KR')
df
# Out:
#      발생년도       경찰서  살인  강도    절도    폭력
# 0    2023   서울중부경찰서   2   1   917  1032
# 1    2023   서울종로경찰서   5   5   607   892
# 2    2023  서울남대문경찰서   1   5   603   575
# 3    2023  서울서대문경찰서   5   0  1194  1026
# 4    2023   서울혜화경찰서   0   0   562   671
# ..    ...       ...  ..  ..   ...   ...
# 255  2023   경남함안경찰서   1   1   107   200
# 256  2023   경남의령경찰서   0   1    50    87
# 257  2023  제주서귀포경찰서   7   2   774  1467
# 258  2023   제주동부경찰서   2   8  1149  1884
# 259  2023   제주서부경찰서   1   6  1345  1746
#
# [260 rows x 6 columns]

# %%
df1 = df[df['경찰서'].str.startswith('서울')]
df1
# Out:
#     발생년도       경찰서  살인  강도    절도    폭력
# 0   2023   서울중부경찰서   2   1   917  1032
# 1   2023   서울종로경찰서   5   5   607   892
# 2   2023  서울남대문경찰서   1   5   603   575
# 3   2023  서울서대문경찰서   5   0  1194  1026
# 4   2023   서울혜화경찰서   0   0   562   671
# 5   2023   서울용산경찰서   3   3   978  1792
# 6   2023   서울성북경찰서   1   0   500   662
# 7   2023  서울동대문경찰서   5   4  1280  1522
# 8   2023   서울마포경찰서   3   4  1472  1908
# 9   2023  서울영등포경찰서  12  10  1854  2232
# 10  2023   서울성동경찰서   2   2   893  1007
# 11  2023   서울동작경찰서   3   3  1183  1262
# 12  2023   서울광진경찰서   2   5  1616  1563
# 13  2023   서울서부경찰서   4   2   790   919
# 14  2023   서울강북경찰서   7   1   917  1431
# 15  2023   서울금천경찰서   4   5   987  1116
# 16  2023   서울중랑경찰서   6   2  1402  1745
# 17  2023   서울강남경찰서   9  10  1636  2322
# 18  2023   서울관악경찰서  16  10  2013  2402
# 19  2023   서울강서경찰서   1   6  1794  2195
# 20  2023   서울강동경찰서   4   5  1676  1569
# 21  2023   서울종암경찰서   0   1   484   622
# 22  2023   서울구로경찰서  12   7  1624  1900
# ...

# %%
#남대문경찰서 = 중
#혜화 = 종
#서부 = 은평
#종암 = 성북
#방배 = 서초
#수서 = 강
print(df1['경찰서'])
# Out:
# 0      서울중부경찰서
# 1      서울종로경찰서
# 2     서울남대문경찰서
# 3     서울서대문경찰서
# 4      서울혜화경찰서
# 5      서울용산경찰서
# 6      서울성북경찰서
# 7     서울동대문경찰서
# 8      서울마포경찰서
# 9     서울영등포경찰서
# 10     서울성동경찰서
# 11     서울동작경찰서
# 12     서울광진경찰서
# 13     서울서부경찰서
# 14     서울강북경찰서
# 15     서울금천경찰서
# 16     서울중랑경찰서
# 17     서울강남경찰서
# 18     서울관악경찰서
# 19     서울강서경찰서
# 20     서울강동경찰서
# 21     서울종암경찰서
# 22     서울구로경찰서
# 23     서울서초경찰서
# 24     서울양천경찰서
# 25     서울송파경찰서
# 26     서울노원경찰서
# 27     서울방배경찰서
# 28     서울은평경찰서
# 29     서울도봉경찰서
# 30     서울수서경찰서
# Name: 경찰서, dtype: object

# %%
시군구 = ['중구','종로구','중구','서대문구','종로구','용산구','성북구','동대문구','마포구','영등포구','성동구','동작구','광진구','은평구','강북구','금천구','중랑구','강남구','관악구','강서구','강동구','성북구','구로구','서초구','양천구','송파구','노원구','서초구','은평구','도봉구','서초구']
구 = ['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서초구','강남구','송파구','강동구']
print(set(구)-set(시군구))
# Out:
# set()

# %%
df1['시군구'] = 시군구
df1
# Out:
# <ipython-input-12-8e4c99d42a7a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['시군구'] = 시군구
#     발생년도       경찰서  살인  강도    절도    폭력   시군구
# 0   2023   서울중부경찰서   2   1   917  1032    중구
# 1   2023   서울종로경찰서   5   5   607   892   종로구
# 2   2023  서울남대문경찰서   1   5   603   575    중구
# 3   2023  서울서대문경찰서   5   0  1194  1026  서대문구
# 4   2023   서울혜화경찰서   0   0   562   671   종로구
# 5   2023   서울용산경찰서   3   3   978  1792   용산구
# 6   2023   서울성북경찰서   1   0   500   662   성북구
# 7   2023  서울동대문경찰서   5   4  1280  1522  동대문구
# 8   2023   서울마포경찰서   3   4  1472  1908   마포구
# 9   2023  서울영등포경찰서  12  10  1854  2232  영등포구
# 10  2023   서울성동경찰서   2   2   893  1007   성동구
# 11  2023   서울동작경찰서   3   3  1183  1262   동작구
# ...

# %%
df1.to_csv('구별_강력범죄.csv',encoding='utf-8')
