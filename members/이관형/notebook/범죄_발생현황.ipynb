# %%
import pandas as pd

# %%
df = pd.read_csv('범죄_발생현황_20250529153855_분석(전년_대비_증감,증감률).csv', encoding='EUC-KR')

# %%
df1 = df.loc[:, df.loc[0].isin(['항목', '구분별(2)', '원데이터'])]

# %%
df2 = df1.loc[2:]

# %%
df2
# Out:
#     항목 구분별(2)    2017    2018    2019    2020    2021    2022    2023
# 2   발생    강력범    7501    6991    6993    6264    5343    6254    6264
# 3   발생    절도범   41146   39175   42203   38292   33529   37579   37038
# 4   발생    폭력범   59399   56075   54723   48344   41756   46783   43132
# 5   발생    지능범   70764   75826   80710   85968   68314   78566   84182
# 6   발생    풍속범    1489    1121    1349    1523    1334     939    5100
# 7   발생  기타형사범   22966   23913   23596   23177   21383   26162   49532
# 8   발생   특별법범  116912  105900   99694   92609   86308   83224   51965
# 9   검거     소계  253068  239291  235360  219683  189139  192540  198771
# 10  검거    강력범    7063    6598    6491    5907    4838    5745    5850
# 11  검거    절도범   21408   19762   21284   19705   17950   20205   21600
# 12  검거    폭력범   51576   48389   47253   41127   35388   39338   37567
# 13  검거    지능범   44976   46561   47539   48780   36227   38584   42791
# ...

# %%
df2.drop(index=9, inplace=True)
df2
# Out:
# <ipython-input-30-cc022e40ada3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop(index=9, inplace=True)
#     항목 구분별(2)    2017    2018   2019   2020   2021   2022   2023
# 2   발생    강력범    7501    6991   6993   6264   5343   6254   6264
# 3   발생    절도범   41146   39175  42203  38292  33529  37579  37038
# 4   발생    폭력범   59399   56075  54723  48344  41756  46783  43132
# 5   발생    지능범   70764   75826  80710  85968  68314  78566  84182
# 6   발생    풍속범    1489    1121   1349   1523   1334    939   5100
# 7   발생  기타형사범   22966   23913  23596  23177  21383  26162  49532
# 8   발생   특별법범  116912  105900  99694  92609  86308  83224  51965
# 10  검거    강력범    7063    6598   6491   5907   4838   5745   5850
# 11  검거    절도범   21408   19762  21284  19705  17950  20205  21600
# ...

# %%
df2.reset_index(drop=True, inplace=True)
df2
# Out:
#     항목 구분별(2)    2017    2018   2019   2020   2021   2022   2023
# 0   발생    강력범    7501    6991   6993   6264   5343   6254   6264
# 1   발생    절도범   41146   39175  42203  38292  33529  37579  37038
# 2   발생    폭력범   59399   56075  54723  48344  41756  46783  43132
# 3   발생    지능범   70764   75826  80710  85968  68314  78566  84182
# 4   발생    풍속범    1489    1121   1349   1523   1334    939   5100
# 5   발생  기타형사범   22966   23913  23596  23177  21383  26162  49532
# 6   발생   특별법범  116912  105900  99694  92609  86308  83224  51965
# 7   검거    강력범    7063    6598   6491   5907   4838   5745   5850
# 8   검거    절도범   21408   19762  21284  19705  17950  20205  21600
# 9   검거    폭력범   51576   48389  47253  41127  35388  39338  37567
# 10  검거    지능범   44976   46561  47539  48780  36227  38584  42791
# 11  검거    풍속범    1332     964   1154   1325   1124    760   4107
# 12  검거  기타형사범   19128   19258  19385  18594  16125  16620  39622
# ...

# %%
dfc = df2.columns.tolist()
dfc[1] = '구분'
df2.columns = dfc

# %%
df2
# Out:
#     항목     구분    2017    2018   2019   2020   2021   2022   2023
# 0   발생    강력범    7501    6991   6993   6264   5343   6254   6264
# 1   발생    절도범   41146   39175  42203  38292  33529  37579  37038
# 2   발생    폭력범   59399   56075  54723  48344  41756  46783  43132
# 3   발생    지능범   70764   75826  80710  85968  68314  78566  84182
# 4   발생    풍속범    1489    1121   1349   1523   1334    939   5100
# 5   발생  기타형사범   22966   23913  23596  23177  21383  26162  49532
# 6   발생   특별법범  116912  105900  99694  92609  86308  83224  51965
# 7   검거    강력범    7063    6598   6491   5907   4838   5745   5850
# 8   검거    절도범   21408   19762  21284  19705  17950  20205  21600
# 9   검거    폭력범   51576   48389  47253  41127  35388  39338  37567
# 10  검거    지능범   44976   46561  47539  48780  36227  38584  42791
# 11  검거    풍속범    1332     964   1154   1325   1124    760   4107
# 12  검거  기타형사범   19128   19258  19385  18594  16125  16620  39622
# ...

# %%
df2.to_csv('범죄_발생현황.csv', encoding='utf-8')
