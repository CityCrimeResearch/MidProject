# %%
import pandas as pd

# %%
df = pd.read_csv('보육시설_구별__20250529114602.csv')
df
# Out:
#     자치구별(1)  자치구별(2)  2023 2023.1  2023.2   2023.3 2023.4 2023.5 2023.6 2023.7
# 0   자치구별(1)  자치구별(2)    합계    국공립  사회복지법인  법인·단체 등     민간     가정   부모협동     직장
# 1       서울시       소계  4431   1836      18       75    912   1258     25    307
# 2       서울시      종로구    66     30       1        1      4      2      -     28
# 3       서울시       중구    66     24       -        6      3      9      -     24
# 4       서울시      용산구   100     36       2        7     15     28      -     12
# 5       서울시      성동구   146     81       -        2     16     40      -      7
# 6       서울시      광진구   138     56       -        -     40     37      1      4
# 7       서울시     동대문구   180     77       -        2     41     52      -      8
# 8       서울시      중랑구   176     66       -        4     58     44      1      3
# 9       서울시      성북구   191     85       2        9     36     51      2      6
# 10      서울시      강북구   115     61       1        1     29     19      2      2
# ...

# %%
df.replace('-', 0)
# Out:
#     자치구별(1)  자치구별(2)  2023 2023.1  2023.2   2023.3 2023.4 2023.5 2023.6 2023.7
# 0   자치구별(1)  자치구별(2)    합계    국공립  사회복지법인  법인·단체 등     민간     가정   부모협동     직장
# 1       서울시       소계  4431   1836      18       75    912   1258     25    307
# 2       서울시      종로구    66     30       1        1      4      2      0     28
# 3       서울시       중구    66     24       0        6      3      9      0     24
# 4       서울시      용산구   100     36       2        7     15     28      0     12
# 5       서울시      성동구   146     81       0        2     16     40      0      7
# 6       서울시      광진구   138     56       0        0     40     37      1      4
# 7       서울시     동대문구   180     77       0        2     41     52      0      8
# 8       서울시      중랑구   176     66       0        4     58     44      1      3
# 9       서울시      성북구   191     85       2        9     36     51      2      6
# 10      서울시      강북구   115     61       1        1     29     19      2      2
# ...

# %%
dfc = ['자치구'] + df.iloc[0, 3:]
df1 = df.copy()
df1.drop(columns=['자치구별(1)', '2023'], inplace=True)
df1
# Out:
#     자치구별(2) 2023.1  2023.2   2023.3 2023.4 2023.5 2023.6 2023.7
# 0   자치구별(2)    국공립  사회복지법인  법인·단체 등     민간     가정   부모협동     직장
# 1        소계   1836      18       75    912   1258     25    307
# 2       종로구     30       1        1      4      2      -     28
# 3        중구     24       -        6      3      9      -     24
# 4       용산구     36       2        7     15     28      -     12
# 5       성동구     81       -        2     16     40      -      7
# 6       광진구     56       -        -     40     37      1      4
# 7      동대문구     77       -        2     41     52      -      8
# 8       중랑구     66       -        4     58     44      1      3
# 9       성북구     85       2        9     36     51      2      6
# 10      강북구     61       1        1     29     19      2      2
# 11      도봉구     65       1        1     40     47      1      3
# 12      노원구     91       2        1     34    146      -      8
# 13      은평구     94       -        6     65     30      1      4
# ...

# %%
dfc = df1.iloc[0]
dfc[0] = '자치구'
# Out:
# <ipython-input-18-25cecd5c07e8>:2: FutureWarning: Series.__setitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To set a value by position, use `ser.iloc[pos] = value`
#   dfc[0] = '자치구'

# %%
dfc
# Out:
# 자치구별(1)        자치구
# 자치구별(2)    자치구별(2)
# 2023            합계
# 2023.1         국공립
# 2023.2      사회복지법인
# 2023.3     법인·단체 등
# 2023.4          민간
# 2023.5          가정
# 2023.6        부모협동
# 2023.7          직장
# Name: 0, dtype: object

# %%
df1.columns = dfc

# %%
df1 = df1.iloc[1:]
df1.replace('-', 0, inplace=True)
df1
# Out:
# <ipython-input-21-3945d8ceab32>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.replace('-', 0, inplace=True)
# 0    자치구   국공립 사회복지법인 법인·단체 등   민간    가정 부모협동   직장
# 1     소계  1836     18      75  912  1258   25  307
# 2    종로구    30      1       1    4     2    0   28
# 3     중구    24      0       6    3     9    0   24
# 4    용산구    36      2       7   15    28    0   12
# 5    성동구    81      0       2   16    40    0    7
# 6    광진구    56      0       0   40    37    1    4
# 7   동대문구    77      0       2   41    52    0    8
# 8    중랑구    66      0       4   58    44    1    3
# 9    성북구    85      2       9   36    51    2    6
# 10   강북구    61      1       1   29    19    2    2
# 11   도봉구    65      1       1   40    47    1    3
# 12   노원구    91      2       1   34   146    0    8
# ...
