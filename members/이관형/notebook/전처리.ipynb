# %%
import pandas as pd

# %%
df = pd.read_csv('등록외국인_현황_국적별_구별__2010년_이후__20250529113444.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Columns: 362 entries, 자치구별(1) to 2023.4/4.179
# dtypes: object(362)
# memory usage: 82.1+ KB

# %%
df.describe()
# Out:
#        자치구별(1)  자치구별(2) 2023.3/4 2023.3/4.1 2023.3/4.2 2023.3/4.3 2023.3/4.4  \
# count       29       29       29         29         29         29         29
# unique       2       27       29         29         29         29         29
# top         합계  자치구별(2)       합계         합계         합계         합계         합계
# freq        26        3        1          1          1          1          1
#
#        2023.3/4.5 2023.3/4.6 2023.3/4.7  ... 2023.4/4.170 2023.4/4.171  \
# count          29         29         29  ...           29           29
# unique         28         29         29  ...           15           21
# top           343         합계         합계  ...            1            9
# freq            2          1          1  ...            6            4
#
#        2023.4/4.172 2023.4/4.173 2023.4/4.174 2023.4/4.175 2023.4/4.176  \
# count            29           29           29           29           29
# unique           15           19           11            9           10
# ...

# %%
df.head()
# Out:
#    자치구별(1)  자치구별(2) 2023.3/4 2023.3/4.1 2023.3/4.2 2023.3/4.3 2023.3/4.4  \
# 0  자치구별(1)  자치구별(2)       합계         합계         합계         합계         합계
# 1  자치구별(1)  자치구별(2)       소계         소계         소계    한국계 중국인    한국계 중국인
# 2  자치구별(1)  자치구별(2)        계         남자         여자          계         남자
# 3       합계       소계   248378     107958     140420      69672      37916
# 4       합계      종로구    11182       4597       6585        849        415
#
#   2023.3/4.5 2023.3/4.6 2023.3/4.7  ... 2023.4/4.170 2023.4/4.171  \
# 0         합계         합계         합계  ...           합계           합계
# 1    한국계 중국인         중국         중국  ...      덴  마  크      모  로  코
# 2         여자          계         남자  ...           여자            계
# 3      31756      61786      21288  ...          131          437
# 4        434       3985       1095  ...            4            6
#
#   2023.4/4.172 2023.4/4.173 2023.4/4.174 2023.4/4.175 2023.4/4.176  \
# ...

# %%
df.transpose()
# Out:
#                    0          1        2       3      4      5      6     7   \
# 자치구별(1)       자치구별(1)    자치구별(1)  자치구별(1)      합계     합계     합계     합계    합계
# 자치구별(2)       자치구별(2)    자치구별(2)  자치구별(2)      소계    종로구     중구    용산구   성동구
# 2023.3/4           합계         소계        계  248378  11182  10420  14540  7177
# 2023.3/4.1         합계         소계       남자  107958   4597   4873   7842  2966
# 2023.3/4.2         합계         소계       여자  140420   6585   5547   6698  4211
# ...               ...        ...      ...     ...    ...    ...    ...   ...
# 2023.4/4.175       합계    이  라  크       남자      65      -      1     41     2
# 2023.4/4.176       합계    이  라  크       여자      58      -      -     37     -
# 2023.4/4.177       합계  기       타        계    5991    234    424   1534   104
# 2023.4/4.178       합계  기       타       남자    2941    103    209    941    49
# 2023.4/4.179       합계  기       타       여자    3050    131    215    593    55
#
# ...

# %%
df.head()
# Out:
#    자치구별(1)  자치구별(2) 2023.3/4 2023.3/4.1 2023.3/4.2 2023.3/4.3 2023.3/4.4  \
# 0  자치구별(1)  자치구별(2)       합계         합계         합계         합계         합계
# 1  자치구별(1)  자치구별(2)       소계         소계         소계    한국계 중국인    한국계 중국인
# 2  자치구별(1)  자치구별(2)        계         남자         여자          계         남자
# 3       합계       소계   248378     107958     140420      69672      37916
# 4       합계      종로구    11182       4597       6585        849        415
#
#   2023.3/4.5 2023.3/4.6 2023.3/4.7  ... 2023.4/4.170 2023.4/4.171  \
# 0         합계         합계         합계  ...           합계           합계
# 1    한국계 중국인         중국         중국  ...      덴  마  크      모  로  코
# 2         여자          계         남자  ...           여자            계
# 3      31756      61786      21288  ...          131          437
# 4        434       3985       1095  ...            4            6
#
#   2023.4/4.172 2023.4/4.173 2023.4/4.174 2023.4/4.175 2023.4/4.176  \
# ...

# %%
df = df.transpose()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29, step=1)

# %%
df1 = df.iloc[: , 1:]

# %%
df1 = df1.transpose()

# %%
df1
# Out:
#                    0          1        2       3      4      5      6     7   \
# 자치구별(2)       자치구별(2)    자치구별(2)  자치구별(2)      소계    종로구     중구    용산구   성동구
# 2023.3/4           합계         소계        계  248378  11182  10420  14540  7177
# 2023.3/4.1         합계         소계       남자  107958   4597   4873   7842  2966
# 2023.3/4.2         합계         소계       여자  140420   6585   5547   6698  4211
# 2023.3/4.3         합계    한국계 중국인        계   69672    849   1066    638  1204
# ...               ...        ...      ...     ...    ...    ...    ...   ...
# 2023.4/4.175       합계    이  라  크       남자      65      -      1     41     2
# 2023.4/4.176       합계    이  라  크       여자      58      -      -     37     -
# 2023.4/4.177       합계  기       타        계    5991    234    424   1534   104
# 2023.4/4.178       합계  기       타       남자    2941    103    209    941    49
# 2023.4/4.179       합계  기       타       여자    3050    131    215    593    55
#
# ...

# %%
df2 = df1.iloc[:181,1:]

# %%
df2.columns = df2.iloc[0]

# %%
df2 = df2.iloc[1:,:]

# %%
df2
# Out:
# 자치구별(2)         자치구별(2) 자치구별(2)      소계    종로구     중구    용산구   성동구    광진구  \
# 2023.3/4             소계       계  248378  11182  10420  14540  7177  15355
# 2023.3/4.1           소계      남자  107958   4597   4873   7842  2966   6167
# 2023.3/4.2           소계      여자  140420   6585   5547   6698  4211   9188
# 2023.3/4.3      한국계 중국인       계   69672    849   1066    638  1204   3437
# 2023.3/4.4      한국계 중국인      남자   37916    415    537    295   599   1723
# ...                 ...     ...     ...    ...    ...    ...   ...    ...
# 2023.3/4.175    이  라  크      남자      68      -      -     45     2      -
# 2023.3/4.176    이  라  크      여자      61      -      -     38     -      -
# 2023.3/4.177  기       타       계    6147    295    424   1713    99    140
# 2023.3/4.178  기       타      남자    3012    129    219   1033    48     52
# 2023.3/4.179  기       타      여자    3135    166    205    680    51     88
#
# 자치구별(2)        동대문구   중랑구  ...   강서구    구로구    금천구   영등포구    동작구    관악구   서초구  \
# ...

# %%
dfc = df2.columns.tolist()
dfc[1] = '국적'
dfc[2] = '성별'
df2.columns = dfc

# %%
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#        자치구별(2)  국적      성별    종로구     중구    용산구   성동구    광진구   동대문구   중랑구  \
# 0           소계   계  248378  11182  10420  14540  7177  15355  17875  5143
# 1           소계  남자  107958   4597   4873   7842  2966   6167   6468  2030
# 2           소계  여자  140420   6585   5547   6698  4211   9188  11407  3113
# 3      한국계 중국인   계   69672    849   1066    638  1204   3437   1594  1121
# 4      한국계 중국인  남자   37916    415    537    295   599   1723    797   522
# ..         ...  ..     ...    ...    ...    ...   ...    ...    ...   ...
# 175    이  라  크  남자      68      -      -     45     2      -     13     -
# 176    이  라  크  여자      61      -      -     38     -      -      9     -
# 177  기       타   계    6147    295    424   1713    99    140    422    40
# 178  기       타  남자    3012    129    219   1033    48     52    184    15
# 179  기       타  여자    3135    166    205    680    51     88    238    25
#
#      ...   강서구    구로구    금천구   영등포구    동작구    관악구   서초구   강남구   송파구   강동구
# ...

# %%
dfc = df2.columns.tolist()
dfc[0] = '국적'
dfc[1] = '성별'
dfc[2] = '소계'
df2.columns = dfc

# %%
df2
# Out:
#             국적  성별      소계    종로구     중구    용산구   성동구    광진구   동대문구   중랑구  \
# 0           소계   계  248378  11182  10420  14540  7177  15355  17875  5143
# 1           소계  남자  107958   4597   4873   7842  2966   6167   6468  2030
# 2           소계  여자  140420   6585   5547   6698  4211   9188  11407  3113
# 3      한국계 중국인   계   69672    849   1066    638  1204   3437   1594  1121
# 4      한국계 중국인  남자   37916    415    537    295   599   1723    797   522
# ..         ...  ..     ...    ...    ...    ...   ...    ...    ...   ...
# 175    이  라  크  남자      68      -      -     45     2      -     13     -
# 176    이  라  크  여자      61      -      -     38     -      -      9     -
# 177  기       타   계    6147    295    424   1713    99    140    422    40
# 178  기       타  남자    3012    129    219   1033    48     52    184    15
# 179  기       타  여자    3135    166    205    680    51     88    238    25
#
#      ...   강서구    구로구    금천구   영등포구    동작구    관악구   서초구   강남구   송파구   강동구
# ...

# %%
df3 = df2[df2['성별'] != '계']
df3
# Out:
#             국적  성별      소계   종로구    중구   용산구   성동구   광진구   동대문구   중랑구  ...  \
# 1           소계  남자  107958  4597  4873  7842  2966  6167   6468  2030  ...
# 2           소계  여자  140420  6585  5547  6698  4211  9188  11407  3113  ...
# 4      한국계 중국인  남자   37916   415   537   295   599  1723    797   522  ...
# 5      한국계 중국인  여자   31756   434   529   343   605  1714    797   599  ...
# 7           중국  남자   21288  1095  1251   200   909  1736   2313   237  ...
# ..         ...  ..     ...   ...   ...   ...   ...   ...    ...   ...  ...
# 173    모  로  코  여자     270     4     4    48     7     7     18     7  ...
# 175    이  라  크  남자      68     -     -    45     2     -     13     -  ...
# 176    이  라  크  여자      61     -     -    38     -     -      9     -  ...
# 178  기       타  남자    3012   129   219  1033    48    52    184    15  ...
# 179  기       타  여자    3135   166   205   680    51    88    238    25  ...
#
#       강서구    구로구   금천구   영등포구   동작구   관악구   서초구   강남구   송파구   강동구
# ...

# %%
df3.reset_index(inplace=True)

# %%
df3
# Out:
#      index         국적  성별      소계   종로구    중구   용산구   성동구   광진구   동대문구  ...  \
# 0        1         소계  남자  107958  4597  4873  7842  2966  6167   6468  ...
# 1        2         소계  여자  140420  6585  5547  6698  4211  9188  11407  ...
# 2        4    한국계 중국인  남자   37916   415   537   295   599  1723    797  ...
# 3        5    한국계 중국인  여자   31756   434   529   343   605  1714    797  ...
# 4        7         중국  남자   21288  1095  1251   200   909  1736   2313  ...
# ..     ...        ...  ..     ...   ...   ...   ...   ...   ...    ...  ...
# 115    173    모  로  코  여자     270     4     4    48     7     7     18  ...
# 116    175    이  라  크  남자      68     -     -    45     2     -     13  ...
# 117    176    이  라  크  여자      61     -     -    38     -     -      9  ...
# 118    178  기       타  남자    3012   129   219  1033    48    52    184  ...
# 119    179  기       타  여자    3135   166   205   680    51    88    238  ...
#
# ...

# %%
df3 = df3.iloc[:, 1:]
df3
# Out:
#             국적  성별      소계   종로구    중구   용산구   성동구   광진구   동대문구   중랑구  ...  \
# 0           소계  남자  107958  4597  4873  7842  2966  6167   6468  2030  ...
# 1           소계  여자  140420  6585  5547  6698  4211  9188  11407  3113  ...
# 2      한국계 중국인  남자   37916   415   537   295   599  1723    797   522  ...
# 3      한국계 중국인  여자   31756   434   529   343   605  1714    797   599  ...
# 4           중국  남자   21288  1095  1251   200   909  1736   2313   237  ...
# ..         ...  ..     ...   ...   ...   ...   ...   ...    ...   ...  ...
# 115    모  로  코  여자     270     4     4    48     7     7     18     7  ...
# 116    이  라  크  남자      68     -     -    45     2     -     13     -  ...
# 117    이  라  크  여자      61     -     -    38     -     -      9     -  ...
# 118  기       타  남자    3012   129   219  1033    48    52    184    15  ...
# 119  기       타  여자    3135   166   205   680    51    88    238    25  ...
#
#       강서구    구로구   금천구   영등포구   동작구   관악구   서초구   강남구   송파구   강동구
# ...

# %%
df3.to_csv('/등록외국인_현황_국적별_구별_2023년3분기.csv', encoding='utf-8')
