# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('등록외국인_현황_국적별_구별__2010년_이후__20250529113444.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Columns: 362 entries, 자치구별(1) to 2023.4/4.179
# dtypes: object(362)
# memory usage: 82.1+ KB

# %%
df.describe()
# Out:
#        자치구별(1)  자치구별(2) 2023.3/4 2023.3/4.1 2023.3/4.2 2023.3/4.3 2023.3/4.4  \
# count       29       29       29         29         29         29         29
# unique       2       27       29         29         29         29         29
# top         합계  자치구별(2)       합계         합계         합계         합계         합계
# freq        26        3        1          1          1          1          1
#
#        2023.3/4.5 2023.3/4.6 2023.3/4.7  ... 2023.4/4.170 2023.4/4.171  \
# count          29         29         29  ...           29           29
# unique         28         29         29  ...           15           21
# top           343         합계         합계  ...            1            9
# freq            2          1          1  ...            6            4
#
#        2023.4/4.172 2023.4/4.173 2023.4/4.174 2023.4/4.175 2023.4/4.176  \
# count            29           29           29           29           29
# unique           15           19           11            9           10
# ...

# %%
df.head()
# Out:
#    자치구별(1)  자치구별(2) 2023.3/4 2023.3/4.1 2023.3/4.2 2023.3/4.3 2023.3/4.4  \
# 0  자치구별(1)  자치구별(2)       합계         합계         합계         합계         합계
# 1  자치구별(1)  자치구별(2)       소계         소계         소계    한국계 중국인    한국계 중국인
# 2  자치구별(1)  자치구별(2)        계         남자         여자          계         남자
# 3       합계       소계   248378     107958     140420      69672      37916
# 4       합계      종로구    11182       4597       6585        849        415
#
#   2023.3/4.5 2023.3/4.6 2023.3/4.7  ... 2023.4/4.170 2023.4/4.171  \
# 0         합계         합계         합계  ...           합계           합계
# 1    한국계 중국인         중국         중국  ...      덴  마  크      모  로  코
# 2         여자          계         남자  ...           여자            계
# 3      31756      61786      21288  ...          131          437
# 4        434       3985       1095  ...            4            6
#
#   2023.4/4.172 2023.4/4.173 2023.4/4.174 2023.4/4.175 2023.4/4.176  \
# ...

# %%
df.transpose()
# Out:
#                    0          1        2       3      4      5      6     7   \
# 자치구별(1)       자치구별(1)    자치구별(1)  자치구별(1)      합계     합계     합계     합계    합계
# 자치구별(2)       자치구별(2)    자치구별(2)  자치구별(2)      소계    종로구     중구    용산구   성동구
# 2023.3/4           합계         소계        계  248378  11182  10420  14540  7177
# 2023.3/4.1         합계         소계       남자  107958   4597   4873   7842  2966
# 2023.3/4.2         합계         소계       여자  140420   6585   5547   6698  4211
# ...               ...        ...      ...     ...    ...    ...    ...   ...
# 2023.4/4.175       합계    이  라  크       남자      65      -      1     41     2
# 2023.4/4.176       합계    이  라  크       여자      58      -      -     37     -
# 2023.4/4.177       합계  기       타        계    5991    234    424   1534   104
# 2023.4/4.178       합계  기       타       남자    2941    103    209    941    49
# 2023.4/4.179       합계  기       타       여자    3050    131    215    593    55
#
# ...

# %%
df.head()
# Out:
#    자치구별(1)  자치구별(2) 2023.3/4 2023.3/4.1 2023.3/4.2 2023.3/4.3 2023.3/4.4  \
# 0  자치구별(1)  자치구별(2)       합계         합계         합계         합계         합계
# 1  자치구별(1)  자치구별(2)       소계         소계         소계    한국계 중국인    한국계 중국인
# 2  자치구별(1)  자치구별(2)        계         남자         여자          계         남자
# 3       합계       소계   248378     107958     140420      69672      37916
# 4       합계      종로구    11182       4597       6585        849        415
#
#   2023.3/4.5 2023.3/4.6 2023.3/4.7  ... 2023.4/4.170 2023.4/4.171  \
# 0         합계         합계         합계  ...           합계           합계
# 1    한국계 중국인         중국         중국  ...      덴  마  크      모  로  코
# 2         여자          계         남자  ...           여자            계
# 3      31756      61786      21288  ...          131          437
# 4        434       3985       1095  ...            4            6
#
#   2023.4/4.172 2023.4/4.173 2023.4/4.174 2023.4/4.175 2023.4/4.176  \
# ...

# %%
df = df.transpose()

# %%
df.index
# Out:
# RangeIndex(start=0, stop=29, step=1)

# %%
df1 = df.iloc[: , 1:]

# %%
df1 = df1.transpose()

# %%
df1
# Out:
#                    0          1        2       3      4      5      6     7   \
# 자치구별(2)       자치구별(2)    자치구별(2)  자치구별(2)      소계    종로구     중구    용산구   성동구
# 2023.3/4           합계         소계        계  248378  11182  10420  14540  7177
# 2023.3/4.1         합계         소계       남자  107958   4597   4873   7842  2966
# 2023.3/4.2         합계         소계       여자  140420   6585   5547   6698  4211
# 2023.3/4.3         합계    한국계 중국인        계   69672    849   1066    638  1204
# ...               ...        ...      ...     ...    ...    ...    ...   ...
# 2023.4/4.175       합계    이  라  크       남자      65      -      1     41     2
# 2023.4/4.176       합계    이  라  크       여자      58      -      -     37     -
# 2023.4/4.177       합계  기       타        계    5991    234    424   1534   104
# 2023.4/4.178       합계  기       타       남자    2941    103    209    941    49
# 2023.4/4.179       합계  기       타       여자    3050    131    215    593    55
#
# ...
