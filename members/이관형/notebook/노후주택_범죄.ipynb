# %%
import pandas as pd

# %%
df_old = pd.read_csv('노후주택.csv')
df_old
# Out:
#     Unnamed: 0  자치구별  20년~30년미만  20년~30년미만(단독주택)  20년~30년미만(아파트트)  \
# 0            1   종로구      16348             1824             4343
# 1            2    중구      16610              932            11137
# 2            3   용산구      23920             2176            14739
# 3            4   성동구      37208             1748            31537
# 4            5   광진구      31308             3988            15832
# 5            6  동대문구      33139             2971            26151
# 6            7   중랑구      39808             3610            28688
# 7            8   성북구      45146             3953            29606
# 8            9   강북구      25776             3847             7710
# 9           10   도봉구      39741             2193            25915
# 10          11   노원구      68208             1336            59727
# 11          12   은평구      37730             2337            10717
# 12          13  서대문구      35226             2100            22237
# ...

# %%
df_old.sort_values(by='자치구별', ascending=True, inplace=True)
df_old.reset_index(drop=True, inplace=True)
df_old.head(3)
# Out:
#    Unnamed: 0 자치구별  20년~30년미만  20년~30년미만(단독주택)  20년~30년미만(아파트트)  \
# 0          23  강남구      41902             3068            22475
# 1          25  강동구      30158             1935            20282
# 2           9  강북구      25776             3847             7710
#
#    20년~30년미만(연립주택)  20년~30년미만(다세대주택)  20년~30년미만(비주거용 건물 내 주택)  30년 이상  \
# 0             2501             13432                      426   58670
# 1             1193              6586                      162   26012
# 2             2116             11920                      183   32058
#
#    30년 이상(단독주택)  30년 이상(아파트트)  30년 이상(연립주택)  30년 이상(다세대주택)  \
# 0          2336         50105          2060           3473
# 1          6669         12898          1633           4126
# 2         12040          7918          1956           9501
#
#    30년 이상(비주거용 건물 내 주택)
# 0                   696
# 1                   686
# 2                   643

# %%
df_ot = pd.read_csv('주택의_종류_및_노후기간별_주택__시군구.csv')
df_ot.head(3)
# Out:
#    행정구역별(시군구)(2)       2023     2023.1     2023.2     2023.3     2023.4  \
# 0  행정구역별(시군구)(2)  20년~30년미만  20년~30년미만  20년~30년미만  20년~30년미만  20년~30년미만
# 1  행정구역별(시군구)(2)          계       단독주택        아파트       연립주택      다세대주택
# 2            종로구      16348       1824       4343       2202       7784
#
#          2023.5  2023.6  2023.7  2023.8  2023.9 2023.1.1       2023.11
# 0     20년~30년미만  30년 이상  30년 이상  30년 이상  30년 이상   30년 이상        30년 이상
# 1  비주거용 건물 내 주택       계    단독주택     아파트    연립주택    다세대주택  비주거용 건물 내 주택
# 2           195   15977    8675    2776    2775     1252           499

# %%
df_ts = pd.read_csv('transposed_seoul_df.csv')
df_ts.head(3)
# Out:
#   Unnamed: 0  살인기수  살인미수등  강도  강간  유사강간  강제추행  기타 강간 강제추행등  방화  절도범죄  ...  \
# 0        종로구     2      1   5  25    10   204            0   4  1173  ...
# 1         중구     0      3   6  30     4   182            0  13  1523  ...
# 2        용산구     1      2   3  45     4   195            0  16   971  ...
#
#    마약범죄  보건범죄  환경범죄  교통범죄  노동범죄  안보범죄  선거범죄  병역범죄  기타범죄  총 범죄 발생 건수
# 0   100   119     1   657     4    11     2    22  1650        9223
# 1    73   108     0   652     3     4     3    18  1612        9793
# 2   200   102     1  1076     4     3     0    30  1817        9042
#
# [3 rows x 40 columns]

# %%
df_ts.sort_values(by='Unnamed: 0', ascending=True, inplace=True)
df_ts.reset_index(drop=True, inplace=True)
df_ts.head(3)
# Out:
#   Unnamed: 0  살인기수  살인미수등  강도   강간  유사강간  강제추행  기타 강간 강제추행등  방화  절도범죄  ...  \
# 0        강남구     2     12  19  181    38   464            2  12  2480  ...
# 1        강동구     1      3   5   34     6    99            0   7  1676  ...
# 2        강북구     2      5   1   21     9   108            1   4   917  ...
#
#    마약범죄  보건범죄  환경범죄  교통범죄  노동범죄  안보범죄  선거범죄  병역범죄  기타범죄  총 범죄 발생 건수
# 0   972   689     6  2989    18     4     3   124  5016       29114
# 1    76    52     1  1045     0     2     2    63  1617        9785
# 2    93    58     1   926     2     2     1    53  1787        8048
#
# [3 rows x 40 columns]

# %%
df_ig = pd.read_csv('주택_인구.csv')
df_ig.head(3)
# Out:
#    Unnamed: 0 행정구역별(읍면동)  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  내국인-남자 (명)  \
# 0           0        종로구   146179   69579   76600     133520       64411
# 1           1         중구   127576   60980   66596     115926       55668
# 2           2        용산구   214791  102923  111868     200568       95425
#
#    내국인-여자 (명)  외국인-계 (명)  외국인-남자 (명)  ...  집단가구 (가구)  외국인가구 (가구)  주택_계 (호)  \
# 0       69109      12659        5168  ...        110        5600     47025
# 1       60258      11650        5312  ...         73        4987     44191
# 2      105143      14223        7498  ...         73        5431     77734
#
#    주택_단독주택 (호)  주택_아파트 (호)  주택_연립주택 (호)  주택_다세대주택 (호)  주택_비주거용 건물 내 주택 (호)  \
# 0        11620       16300         5544         12695                  866
# 1         5735       28126         1873          7625                  832
# 2        13370       39806         3921         19978                  659
#
#    주택 이외의 거처_계 (호)   주택_계
# 0             7033  47025
# ...

# %%
df_ig.sort_values(by='행정구역별(읍면동)', ascending=True, inplace=True)
df_ig.reset_index(drop=True, inplace=True)
df_ig.head(3)
# Out:
#    Unnamed: 0 행정구역별(읍면동)  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  내국인-남자 (명)  \
# 0          22        강남구   511084  244560  266524     502796      240802
# 1          24        강동구   446561  217965  228596     440018      215025
# 2           8        강북구   284155  136266  147889     277553      133893
#
#    내국인-여자 (명)  외국인-계 (명)  외국인-남자 (명)  ...  집단가구 (가구)  외국인가구 (가구)  주택_계 (호)  \
# 0      261994       8288        3758  ...         76        3450    184608
# 1      224993       6543        2940  ...         55        2658    151178
# 2      143660       6602        2373  ...         90        2985    100418
#
#    주택_단독주택 (호)  주택_아파트 (호)  주택_연립주택 (호)  주택_다세대주택 (호)  주택_비주거용 건물 내 주택 (호)  \
# 0         6161      138025         5645         33229                 1548
# 1         9410       97890         3252         39584                 1042
# 2        17068       36541         4903         40911                  995
#
#    주택 이외의 거처_계 (호)    주택_계
# 0            15217  184608
# ...

# %%
df1 = pd.DataFrame()

# %%
df1['행정구'] = df_old['자치구별']
df1['노후주택'] = df_old['20년~30년미만']
df1['극노후주택'] = df_old['30년 이상']
df1['인구'] = df_ig['총인구 (명)']
df1['주택'] = df_ig['주택_계']

# %%
df1.iloc[:,1:].corr()
# Out:
#            노후주택     극노후주택        인구        주택
# 노후주택   1.000000  0.670138  0.770145  0.797579
# 극노후주택  0.670138  1.000000  0.612084  0.707979
# 인구     0.770145  0.612084  1.000000  0.956186
# 주택     0.797579  0.707979  0.956186  1.000000

# %%
df1['범죄건수'] = df_ts['총 범죄 발생 건수']
# df1['인구당범죄건수'] = df1['범죄건수'] / df1['인구'] * 10000
# df1['노후주택비율']  = (df1['노후주택'] + df1['극노후주택']) / df1['주택']
# df1['극노후주택비율'] = df1['극노후주택'] / df1['주택']
df1.iloc[:,1:].corr(method='spearman')
# Out:
#            노후주택     극노후주택        인구        주택      범죄건수
# 노후주택   1.000000  0.679231  0.773846  0.760769  0.291538
# 극노후주택  0.679231  1.000000  0.753077  0.773846  0.430769
# 인구     0.773846  0.753077  1.000000  0.957692  0.653077
# 주택     0.760769  0.773846  0.957692  1.000000  0.576154
# 범죄건수   0.291538  0.430769  0.653077  0.576154  1.000000

# %%
df1.to_csv('노후주택_범죄.csv', encoding='utf-8')
