# %%
import pandas as pd

# %%
df_ph = pd.read_csv('인구__가구_및_주택_시군구.csv')
df_ph
# Out:
#     행정구역별(읍면동)     2023   2023.1   2023.2     2023.3      2023.4      2023.5  \
# 0   행정구역별(읍면동)  총인구 (명)   남자 (명)   여자 (명)  내국인-계 (명)  내국인-남자 (명)  내국인-여자 (명)
# 1        서울특별시  9384512  4523958  4860554    9018373     4357962     4660411
# 2          종로구   146179    69579    76600     133520       64411       69109
# 3           중구   127576    60980    66596     115926       55668       60258
# 4          용산구   214791   102923   111868     200568       95425      105143
# 5          성동구   277683   134488   143195     267315      129971      137344
# 6          광진구   348160   166527   181633     326550      157303      169247
# 7         동대문구   355999   171927   184072     332745      162910      169835
# 8          중랑구   376621   183685   192936     368837      180565      188272
# 9          성북구   432874   205261   227613     417166      199341      217825
# 10         강북구   284155   136266   147889     277553      133893      143660
# ...

# %%
df1 = df_ph.iloc[2:]
df1.columns = df_ph.iloc[0]
df1
# Out:
# 0  행정구역별(읍면동) 총인구 (명)  남자 (명)  여자 (명) 내국인-계 (명) 내국인-남자 (명) 내국인-여자 (명)  \
# 2         종로구  146179   69579   76600    133520      64411      69109
# 3          중구  127576   60980   66596    115926      55668      60258
# 4         용산구  214791  102923  111868    200568      95425     105143
# 5         성동구  277683  134488  143195    267315     129971     137344
# 6         광진구  348160  166527  181633    326550     157303     169247
# 7        동대문구  355999  171927  184072    332745     162910     169835
# 8         중랑구  376621  183685  192936    368837     180565     188272
# 9         성북구  432874  205261  227613    417166     199341     217825
# 10        강북구  284155  136266  147889    277553     133893     143660
# 11        도봉구  299931  144315  155616    296367     143052     153315
# 12        노원구  492979  236495  256484    486643     233868     252775
# 13        은평구  452988  214646  238342    447341     212358     234983
# ...

# %%
df1.reset_index(drop=True, inplace=True)
df1
# Out:
# 0  행정구역별(읍면동) 총인구 (명)  남자 (명)  여자 (명) 내국인-계 (명) 내국인-남자 (명) 내국인-여자 (명)  \
# 0         종로구  146179   69579   76600    133520      64411      69109
# 1          중구  127576   60980   66596    115926      55668      60258
# 2         용산구  214791  102923  111868    200568      95425     105143
# 3         성동구  277683  134488  143195    267315     129971     137344
# 4         광진구  348160  166527  181633    326550     157303     169247
# 5        동대문구  355999  171927  184072    332745     162910     169835
# 6         중랑구  376621  183685  192936    368837     180565     188272
# 7         성북구  432874  205261  227613    417166     199341     217825
# 8         강북구  284155  136266  147889    277553     133893     143660
# 9         도봉구  299931  144315  155616    296367     143052     153315
# 10        노원구  492979  236495  256484    486643     233868     252775
# 11        은평구  452988  214646  238342    447341     212358     234983
# ...

# %%
df1.sort_values(by='주택_계 (호)', ascending=False)
# Out:
# 0  행정구역별(읍면동) 총인구 (명)  남자 (명)  여자 (명) 내국인-계 (명) 내국인-남자 (명) 내국인-여자 (명)  \
# 4         광진구  348160  166527  181633    326550     157303     169247
# 3         성동구  277683  134488  143195    267315     129971     137344
# 2         용산구  214791  102923  111868    200568      95425     105143
# 17        금천구  245860  124278  121582    220365     110564     109801
# 0         종로구  146179   69579   76600    133520      64411      69109
# 1          중구  127576   60980   66596    115926      55668      60258
# 23        송파구  630744  303004  327740    621338     298804     322534
# 15        강서구  549557  262646  286911    541039     258948     282091
# 10        노원구  492979  236495  256484    486643     233868     252775
# 22        강남구  511084  244560  266524    502796     240802     261994
# 11        은평구  452988  214646  238342    447341     212358     234983
# 24        강동구  446561  217965  228596    440018     215025     224993
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   행정구역별(읍면동)           25 non-null     object
#  1   총인구 (명)              25 non-null     object
#  2   남자 (명)               25 non-null     object
#  3   여자 (명)               25 non-null     object
#  4   내국인-계 (명)            25 non-null     object
#  5   내국인-남자 (명)           25 non-null     object
#  6   내국인-여자 (명)           25 non-null     object
#  7   외국인-계 (명)            25 non-null     object
#  8   외국인-남자 (명)           25 non-null     object
#  9   외국인-여자 (명)           25 non-null     object
#  10  가구-계 (가구)            25 non-null     object
#  11  일반가구 (가구)            25 non-null     object
#  12  집단가구 (가구)            25 non-null     object
#  13  외국인가구 (가구)           25 non-null     object
#  14  주택_계 (호)             25 non-null     object
# ...

# %%
df1['주택_계'] = df1['주택_계 (호)'].astype(int)
# Out:
# <ipython-input-10-616a76f8fade>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['주택_계'] = df1['주택_계 (호)'].astype(int)

# %%
df1.sort_values(by='주택_계', ascending=False)
# Out:
# 0  행정구역별(읍면동) 총인구 (명)  남자 (명)  여자 (명) 내국인-계 (명) 내국인-남자 (명) 내국인-여자 (명)  \
# 23        송파구  630744  303004  327740    621338     298804     322534
# 15        강서구  549557  262646  286911    541039     258948     282091
# 10        노원구  492979  236495  256484    486643     233868     252775
# 22        강남구  511084  244560  266524    502796     240802     261994
# 11        은평구  452988  214646  238342    447341     212358     234983
# 24        강동구  446561  217965  228596    440018     215025     224993
# 14        양천구  422248  205753  216495    416909     203517     213392
# 7         성북구  432874  205261  227613    417166     199341     217825
# 16        구로구  423397  210034  213363    380160     186226     193934
# 21        서초구  385267  183751  201516    378883     180810     198073
# 20        관악구  493677  246553  247124    469484     236345     233139
# 13        마포구  361380  167854  193526    348439     162981     185458
# ...

# %%
df_ht = pd.read_csv('주택의_종류_및_노후기간별_주택__시군구.csv')
df_ht
# Out:
#     행정구역별(시군구)(2)       2023     2023.1     2023.2     2023.3     2023.4  \
# 0   행정구역별(시군구)(2)  20년~30년미만  20년~30년미만  20년~30년미만  20년~30년미만  20년~30년미만
# 1   행정구역별(시군구)(2)          계       단독주택        아파트       연립주택      다세대주택
# 2             종로구      16348       1824       4343       2202       7784
# 3              중구      16610        932      11137       1182       3181
# 4             용산구      23920       2176      14739       1806       5104
# 5             성동구      37208       1748      31537        358       3377
# 6             광진구      31308       3988      15832       1846       9400
# 7            동대문구      33139       2971      26151        890       2885
# 8             중랑구      39808       3610      28688       1308       5915
# 9             성북구      45146       3953      29606       2643       8617
# 10            강북구      25776       3847       7710       2116      11920
# 11            도봉구      39741       2193      25915       1712       9786
# ...

# %%
dfhtc = df_ht.iloc[0] + ' ' + df_ht.iloc[1]
df2 = df_ht.copy()

# %%
dfhtc = dfhtc.to_list()
dfhtc[0] = '행정구'
dfhtc
# Out:
# ['행정구',
#  '20년~30년미만 계',
#  '20년~30년미만 단독주택',
#  '20년~30년미만 아파트',
#  '20년~30년미만 연립주택',
#  '20년~30년미만 다세대주택',
#  '20년~30년미만 비주거용 건물 내 주택',
#  '30년 이상 계',
#  '30년 이상 단독주택',
#  '30년 이상 아파트',
#  '30년 이상 연립주택',
#  '30년 이상 다세대주택',
#  '30년 이상 비주거용 건물 내 주택']

# %%
df2.columns = dfhtc
df2
# Out:
#               행정구 20년~30년미만 계 20년~30년미만 단독주택 20년~30년미만 아파트 20년~30년미만 연립주택  \
# 0   행정구역별(시군구)(2)   20년~30년미만      20년~30년미만     20년~30년미만      20년~30년미만
# 1   행정구역별(시군구)(2)           계           단독주택           아파트           연립주택
# 2             종로구       16348           1824          4343           2202
# 3              중구       16610            932         11137           1182
# 4             용산구       23920           2176         14739           1806
# 5             성동구       37208           1748         31537            358
# 6             광진구       31308           3988         15832           1846
# 7            동대문구       33139           2971         26151            890
# 8             중랑구       39808           3610         28688           1308
# 9             성북구       45146           3953         29606           2643
# 10            강북구       25776           3847          7710           2116
# 11            도봉구       39741           2193         25915           1712
# ...

# %%
df22 = df2.loc[:,df2.iloc[1] != '계']
df22
# Out:
#               행정구 20년~30년미만 단독주택 20년~30년미만 아파트 20년~30년미만 연립주택 20년~30년미만 다세대주택  \
# 0   행정구역별(시군구)(2)      20년~30년미만     20년~30년미만      20년~30년미만       20년~30년미만
# 1   행정구역별(시군구)(2)           단독주택           아파트           연립주택           다세대주택
# 2             종로구           1824          4343           2202            7784
# 3              중구            932         11137           1182            3181
# 4             용산구           2176         14739           1806            5104
# 5             성동구           1748         31537            358            3377
# 6             광진구           3988         15832           1846            9400
# 7            동대문구           2971         26151            890            2885
# 8             중랑구           3610         28688           1308            5915
# 9             성북구           3953         29606           2643            8617
# 10            강북구           3847          7710           2116           11920
# ...

# %%
df22 = df22.iloc[2:]

# %%
df22.reset_index(drop=True, inplace=True)
df22
# Out:
#      행정구 20년~30년미만 단독주택 20년~30년미만 아파트 20년~30년미만 연립주택 20년~30년미만 다세대주택  \
# 0    종로구           1824          4343           2202            7784
# 1     중구            932         11137           1182            3181
# 2    용산구           2176         14739           1806            5104
# 3    성동구           1748         31537            358            3377
# 4    광진구           3988         15832           1846            9400
# 5   동대문구           2971         26151            890            2885
# 6    중랑구           3610         28688           1308            5915
# 7    성북구           3953         29606           2643            8617
# 8    강북구           3847          7710           2116           11920
# 9    도봉구           2193         25915           1712            9786
# 10   노원구           1336         59727           2066            4879
# 11   은평구           2337         10717           2788           21646
# 12  서대문구           2100         22237           2599            8088
# ...

# %%
df_fr = pd.read_csv('등록외국인_현황_국적별_구별_2023년3분기.csv')
df_fr
# Out:
#      Unnamed: 0         국적  성별      소계   종로구    중구   용산구   성동구   광진구   동대문구  \
# 0             0         소계  남자  107958  4597  4873  7842  2966  6167   6468
# 1             1         소계  여자  140420  6585  5547  6698  4211  9188  11407
# 2             2    한국계 중국인  남자   37916   415   537   295   599  1723    797
# 3             3    한국계 중국인  여자   31756   434   529   343   605  1714    797
# 4             4         중국  남자   21288  1095  1251   200   909  1736   2313
# ..          ...        ...  ..     ...   ...   ...   ...   ...   ...    ...
# 115         115    모  로  코  여자     270     4     4    48     7     7     18
# 116         116    이  라  크  남자      68     -     -    45     2     -     13
# 117         117    이  라  크  여자      61     -     -    38     -     -      9
# 118         118  기       타  남자    3012   129   219  1033    48    52    184
# 119         119  기       타  여자    3135   166   205   680    51    88    238
#
# ...

# %%
df3 = df_fr.iloc[2:,1:]
df3.reset_index(drop=True, inplace=True)
df3
# Out:
#             국적  성별     소계   종로구    중구   용산구   성동구   광진구  동대문구  중랑구  ...  강서구  \
# 0      한국계 중국인  남자  37916   415   537   295   599  1723   797  522  ...  860
# 1      한국계 중국인  여자  31756   434   529   343   605  1714   797  599  ...  859
# 2           중국  남자  21288  1095  1251   200   909  1736  2313  237  ...  329
# 3           중국  여자  40498  2890  1725   375  1631  3227  5365  487  ...  683
# 4           미국  남자   5423   526   173  1230   118   109   107   35  ...   89
# ..         ...  ..    ...   ...   ...   ...   ...   ...   ...  ...  ...  ...
# 113    모  로  코  여자    270     4     4    48     7     7    18    7  ...   10
# 114    이  라  크  남자     68     -     -    45     2     -    13    -  ...    -
# 115    이  라  크  여자     61     -     -    38     -     -     9    -  ...    1
# 116  기       타  남자   3012   129   219  1033    48    52   184   15  ...   48
# 117  기       타  여자   3135   166   205   680    51    88   238   25  ...   41
#
# ...

# %%
df33 = df3.T

# %%
df3c = df33.iloc[0] + '_' + df33.iloc[1]
df3c = df3c.to_list()
df3c = [d.replace(' ','').replace('_', ' ').replace('계중', '계 중') for d in df3c]
df3c.reverse()
df3c.append('행정구')
df3c.reverse()
df3c
# Out:
# ['행정구',
#  '한국계 중국인 남자',
#  '한국계 중국인 여자',
#  '중국 남자',
#  '중국 여자',
#  '미국 남자',
#  '미국 여자',
#  '타이완 남자',
#  '타이완 여자',
#  '일본 남자',
#  '일본 여자',
#  '베트남 남자',
#  '베트남 여자',
#  '몽골 남자',
#  '몽골 여자',
#  '필리핀 남자',
#  '필리핀 여자',
#  '캐나다 남자',
#  '캐나다 여자',
#  '인도 남자',
#  '인도 여자',
#  '우즈베키스탄 남자',
#  '우즈베키스탄 여자',
#  '영국 남자',
#  '영국 여자',
#  '프랑스 남자',
#  '프랑스 여자',
#  '타이 남자',
#  '타이 여자',
#  '러시아(연방) 남자',
#  '러시아(연방) 여자',
#  '독일 남자',
#  '독일 여자',
#  '오스트레일리아 남자',
#  '오스트레일리아 여자',
#  '네팔 남자',
#  '네팔 여자',
#  '파키스탄 남자',
#  '파키스탄 여자',
#  '인도네시아 남자',
#  '인도네시아 여자',
#  '나이지리아 남자',
#  '나이지리아 여자',
#  '말레이시아 남자',
#  '말레이시아 여자',
#  '방글라데시 남자',
#  '방글라데시 여자',
#  '캄보디아 남자',
#  '캄보디아 여자',
#  '사우디아라비아 남자',
#  '사우디아라비아 여자',
#  '홍콩 남자',
#  '홍콩 여자',
#  '뉴질랜드 남자',
#  '뉴질랜드 여자',
#  '카자흐스탄 남자',
#  '카자흐스탄 여자',
#  '스리랑카 남자',
#  '스리랑카 여자',
#  '남아프리카공화국 남자',
#  '남아프리카공화국 여자',
#  '미얀마 남자',
#  '미얀마 여자',
#  '싱가포르 남자',
#  '싱가포르 여자',
#  '이란 남자',
#  '이란 여자',
#  '브라질 남자',
#  '브라질 여자',
#  '아일랜드 남자',
#  '아일랜드 여자',
#  '스웨덴 남자',
# ...

# %%
df33.reset_index(inplace=True)
df33.columns = df3c
df33
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-ecf84a30e572> in <cell line: 0>()
#       1 df33.reset_index(inplace=True)
# ----> 2 df33.columns = df3c
#       3 df33 = df33.iloc[3:]
#       4 df33
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    6311         try:
#    6312             object.__getattribute__(self, name)
# -> 6313             return object.__setattr__(self, name, value)
#    6314         except AttributeError:
#    6315             pass
#
# properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     812         """
#     813         labels = ensure_index(labels)
# --> 814         self._mgr.set_axis(axis, labels)
#     815         self._clear_item_cache()
#     816
#
# ...

# %%
df33 = df33.iloc[3:]
df33
# Out:
#     index   행정구 한국계 중국인 남자 한국계 중국인 여자 중국 남자 중국 여자 미국 남자 미국 여자 타이완 남자 타이완 여자  \
# 3       3   종로구        415        434  1095  2890   526   460     84    189
# 4       4    중구        537        529  1251  1725   173   121    253    308
# 5       5   용산구        295        343   200   375  1230   939    155    160
# 6       6   성동구        599        605   909  1631   118   105     71     80
# 7       7   광진구       1723       1714  1736  3227   109   131     49    117
# 8       8  동대문구        797        797  2313  5365   107   164     86    313
# 9       9   중랑구        522        599   237   487    35    37     32     51
# 10     10   성북구        339        343  1400  2874   222   302    107    182
# 11     11   강북구        360        398   264   738    51    46     51     76
# 12     12   도봉구        159        178    99   278    40    43     18     27
# 13     13   노원구        187        215   345   483   101   104     30     43
# ...

# %%
df34 = df33.iloc[:,1:]
df34
# Out:
#      행정구 한국계 중국인 남자 한국계 중국인 여자 중국 남자 중국 여자 미국 남자 미국 여자 타이완 남자 타이완 여자 일본 남자  \
# 3    종로구        415        434  1095  2890   526   460     84    189   157
# 4     중구        537        529  1251  1725   173   121    253    308   115
# 5    용산구        295        343   200   375  1230   939    155    160   489
# 6    성동구        599        605   909  1631   118   105     71     80    37
# 7    광진구       1723       1714  1736  3227   109   131     49    117    64
# 8   동대문구        797        797  2313  5365   107   164     86    313    62
# 9    중랑구        522        599   237   487    35    37     32     51    13
# 10   성북구        339        343  1400  2874   222   302    107    182    53
# 11   강북구        360        398   264   738    51    46     51     76     8
# 12   도봉구        159        178    99   278    40    43     18     27    18
# 13   노원구        187        215   345   483   101   104     30     43    18
# ...

# %%
df34.reset_index(drop=True, inplace=True)
df34
# Out:
#      행정구 한국계 중국인 남자 한국계 중국인 여자 중국 남자 중국 여자 미국 남자 미국 여자 타이완 남자 타이완 여자 일본 남자  \
# 0    종로구        415        434  1095  2890   526   460     84    189   157
# 1     중구        537        529  1251  1725   173   121    253    308   115
# 2    용산구        295        343   200   375  1230   939    155    160   489
# 3    성동구        599        605   909  1631   118   105     71     80    37
# 4    광진구       1723       1714  1736  3227   109   131     49    117    64
# 5   동대문구        797        797  2313  5365   107   164     86    313    62
# 6    중랑구        522        599   237   487    35    37     32     51    13
# 7    성북구        339        343  1400  2874   222   302    107    182    53
# 8    강북구        360        398   264   738    51    46     51     76     8
# 9    도봉구        159        178    99   278    40    43     18     27    18
# 10   노원구        187        215   345   483   101   104     30     43    18
# ...

# %%
df_ho = pd.read_csv('구별_주택소유현황_2023.csv')
df_ho
# Out:
#     Unnamed: 0   자치구   총 주택수  개인소유 주택수  동일시군구 거주자 소유주택  동일시도내 타시군구 거주자 소유주택  \
# 0            0   종로구   47025     42893           28803                 7431
# 1            1    중구   44191     35925           21361                 8008
# 2            2   용산구   77734     69243           37042                16378
# 3            3   성동구   91252     79491           52389                13720
# 4            4   광진구   95286     89376           65132                11202
# 5            5  동대문구  110169     93716           66774                13085
# 6            6   중랑구  119961    103235           78922                11015
# 7            7   성북구  143240    126824           93625                16187
# 8            8   강북구  100418     85889           63019                11251
# 9            9   도봉구  109465    102595           78061                11098
# 10          10   노원구  192926    161429          116067                19399
# ...

# %%
df1.describe()
# Out:
# 0               주택_계
# count      25.000000
# mean   126213.240000
# std     44829.164129
# min     44191.000000
# 25%    100418.000000
# 50%    122058.000000
# 75%    147619.000000
# max    221082.000000

# %%
df1.to_csv('주택_인구.csv', encoding='utf-8')
df22.to_csv('노후주택.csv', encoding='utf-8')
df34.to_csv('외국인_인구.csv', encoding='utf-8')

# %%
df4 = df_ho.iloc[:,1:]
df4
# Out:
#      자치구   총 주택수  개인소유 주택수  동일시군구 거주자 소유주택  동일시도내 타시군구 거주자 소유주택  타시도 거주자 소유주택  \
# 0    종로구   47025     42893           28803                 7431          6659
# 1     중구   44191     35925           21361                 8008          6556
# 2    용산구   77734     69243           37042                16378         15823
# 3    성동구   91252     79491           52389                13720         13382
# 4    광진구   95286     89376           65132                11202         13042
# 5   동대문구  110169     93716           66774                13085         13857
# 6    중랑구  119961    103235           78922                11015         13298
# 7    성북구  143240    126824           93625                16187         17012
# 8    강북구  100418     85889           63019                11251         11619
# 9    도봉구  109465    102595           78061                11098         13436
# 10   노원구  192926    161429          116067                19399         25963
# ...

# %%
df4.to_csv('주택_가구')
