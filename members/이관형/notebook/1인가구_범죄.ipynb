# %%
import pandas as pd

# %%
df_1 = pd.read_csv('1인가구합.csv')
df_ts = pd.read_csv('transposed_seoul_df.csv')
print(df_1.columns)
print(df_ts.columns)
# Out:
# Index(['Unnamed: 0', '자치구별', '1인가구수(남자)', '1인가구수(여자)'], dtype='object')
# Index(['Unnamed: 0', '살인기수', '살인미수등', '강도', '강간', '유사강간', '강제추행',
#        '기타 강간 강제추행등', '방화', '절도범죄', '상해', '폭행', '체포감금', '협박', '약취 유인', '폭력행위등',
#        '공갈', '손괴', '직무유기', '직권남용', '증수뢰', '통화', '문서 인장', '유가증권인지', '사기', '횡령',
#        '배임', '성풍속범죄', '도박범죄', '특별경제범죄', '마약범죄', '보건범죄', '환경범죄', '교통범죄', '노동범죄',
#        '안보범죄', '선거범죄', '병역범죄', '기타범죄', '총 범죄 발생 건수'],
#       dtype='object')

# %%
df1 = pd.DataFrame()
df_1.sort_values(by='자치구별', ascending=True, inplace=True)
df_ts.sort_values(by='Unnamed: 0', ascending=True, inplace=True)
df_1.head(3)
df_ts.head(3)
# Out:
#    Unnamed: 0  살인기수  살인미수등  강도   강간  유사강간  강제추행  기타 강간 강제추행등  방화  절도범죄  ...  \
# 22        강남구     2     12  19  181    38   464            2  12  2480  ...
# 24        강동구     1      3   5   34     6    99            0   7  1676  ...
# 8         강북구     2      5   1   21     9   108            1   4   917  ...
#
#     마약범죄  보건범죄  환경범죄  교통범죄  노동범죄  안보범죄  선거범죄  병역범죄  기타범죄  총 범죄 발생 건수
# 22   972   689     6  2989    18     4     3   124  5016       29114
# 24    76    52     1  1045     0     2     2    63  1617        9785
# 8     93    58     1   926     2     2     1    53  1787        8048
#
# [3 rows x 40 columns]

# %%
df_1.reset_index(drop=True, inplace=True)
df_ts.reset_index(drop=True, inplace=True)

# %%
df1['행정구'] = df_1['자치구별']
df1['1인가구수'] = df_1['1인가구수(남자)'] + df_1['1인가구수(여자)']
df1['범죄건수'] = df_ts['총 범죄 발생 건수']

# %%
df_ji = pd.read_csv('주택_인구.csv')
df_ji
# Out:
#     Unnamed: 0 행정구역별(읍면동)  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  내국인-남자 (명)  \
# 0            0        종로구   146179   69579   76600     133520       64411
# 1            1         중구   127576   60980   66596     115926       55668
# 2            2        용산구   214791  102923  111868     200568       95425
# 3            3        성동구   277683  134488  143195     267315      129971
# 4            4        광진구   348160  166527  181633     326550      157303
# 5            5       동대문구   355999  171927  184072     332745      162910
# 6            6        중랑구   376621  183685  192936     368837      180565
# 7            7        성북구   432874  205261  227613     417166      199341
# 8            8        강북구   284155  136266  147889     277553      133893
# 9            9        도봉구   299931  144315  155616     296367      143052
# 10          10        노원구   492979  236495  256484     486643      233868
# 11          11        은평구   452988  214646  238342     447341      212358
# ...

# %%
df_ji.sort_values(by='행정구역별(읍면동)', ascending=True, inplace=True)
df_ji.head(3)
# Out:
#     Unnamed: 0 행정구역별(읍면동)  총인구 (명)  남자 (명)  여자 (명)  내국인-계 (명)  내국인-남자 (명)  \
# 22          22        강남구   511084  244560  266524     502796      240802
# 24          24        강동구   446561  217965  228596     440018      215025
# 8            8        강북구   284155  136266  147889     277553      133893
#
#     내국인-여자 (명)  외국인-계 (명)  외국인-남자 (명)  ...  집단가구 (가구)  외국인가구 (가구)  주택_계 (호)  \
# 22      261994       8288        3758  ...         76        3450    184608
# 24      224993       6543        2940  ...         55        2658    151178
# 8       143660       6602        2373  ...         90        2985    100418
#
#     주택_단독주택 (호)  주택_아파트 (호)  주택_연립주택 (호)  주택_다세대주택 (호)  주택_비주거용 건물 내 주택 (호)  \
# 22         6161      138025         5645         33229                 1548
# 24         9410       97890         3252         39584                 1042
# 8         17068       36541         4903         40911                  995
#
#     주택 이외의 거처_계 (호)    주택_계
# ...

# %%
df_ji.reset_index(drop=True, inplace=True)

# %%
df1['인구'] = df_ji['총인구 (명)']
df1.head(3)
# Out:
#    행정구  1인가구수   범죄건수      인구
# 0  강남구  76809  29114  511084
# 1  강동구  62943   9785  446561
# 2  강북구  52659   8048  284155

# %%
# df1['인구당1인가구'] = df1['1인가구수'] / df1['인구']
# df1['인구당범죄건수'] = df1['범죄건수'] / df1['인구']
df1.to_csv('1인가구_범죄.csv', encoding='utf-8')
